# %%
from dotenv import load_dotenv; load_dotenv()

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import date
from tqdm import tqdm

from pandarallel import pandarallel
pandarallel.initialize()
from mlb_dataloader.util.data_helpers import sql_read
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %% [markdown]
# # readers

# %%
readers = sql_read(f'''SELECT * FROM "HAHATON".data_reader''')
print(readers.shape)
readers.head()
# Out:
# (562133, 3)
#        id  birth_date        age
# 0  366670  1974-10-14  46.079452
# 1  235264  1978-06-01  42.446575
# 2  133225  1976-01-06  44.849315
# 3  556716  1989-01-28  31.778082
# 4   52086  1955-08-14  65.260274

# %% [markdown]
# # catalog

# %%
catalog = sql_read(f'''SELECT * FROM "HAHATON".data_catalog''')
print(catalog.shape)
catalog.head()
# Out:
# (1370457, 11)
#       id                       author  \
# 0      1  Устинова Татьяна Витальевна
# 1      2                         None
# 2  11185                         None
# 3  11157                         None
# 4  11161                         None
#
#                                                title    city  \
# 0                                      Призрак Канта  Москва
# 1                                      Наука и жизнь  Москва
# 2  Путешествие на зеленый свет (или Школа юного п...  Москва
# 3                                           Мурзилка  Москва
# 4                                           Нарконет  Москва
#
#                               publisher   year  \
# 0                                 Эксмо   2018
# 1  АНО Редакция журнала «Наука и жизнь»  1938-
# 2                                  Кедр   None
# 3           Редакция журнала "Мурзилка"  1924-
# 4                              Нарконет  1999-
#
#                                   series  \
# 0  Татьяна Устинова. Первая среди лучших
# 1                                    nan
# 2                                    nan
# 3                                    nan
# 4                                    nan
#
#                                               tags    article age_rating  \
# 0  Художественная литература ; Российский детектив  84(2Рос)6        16+
# 1                              Наука. Науковедение         72        12+
# 2                      Техника и технические науки          3         6+
# 3                 Литература для детей и юношества         84         6+
# 4                       Здравоохранение и медицина          5        12+
#
#   cover_url
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None

# %%
catalog[catalog.id == 594528]
# Out:
#             id                     author                              title  \
# 817130  594528  Машинский Семен Иосифович  С. Т. Аксаков. Жизнь и творчество
#
#           city    publisher  year series tags article age_rating cover_url
# 817130  Москва  Гослитиздат  1961    nan  nan  8Р1XIX       None      None

# %% [markdown]
# ### Проблема: у многих записей в каталоге одинаковые автор и заглавие.
# ### Необходимо чтобы это считалось одним экземпляром

# %%
catalog['unique'] = catalog[['author', 'title']].parallel_apply(
    lambda x: frozenset(str(x[0]).strip().split()) | frozenset(str(x[1]).strip().split()), axis=1)
catalog.head()
# Out:
#       id                       author  \
# 0      1  Устинова Татьяна Витальевна
# 1      2                         None
# 2  11185                         None
# 3  11157                         None
# 4  11161                         None
#
#                                                title    city  \
# 0                                      Призрак Канта  Москва
# 1                                      Наука и жизнь  Москва
# 2  Путешествие на зеленый свет (или Школа юного п...  Москва
# 3                                           Мурзилка  Москва
# 4                                           Нарконет  Москва
#
#                               publisher   year  \
# 0                                 Эксмо   2018
# 1  АНО Редакция журнала «Наука и жизнь»  1938-
# 2                                  Кедр   None
# 3           Редакция журнала "Мурзилка"  1924-
# 4                              Нарконет  1999-
#
#                                   series  \
# 0  Татьяна Устинова. Первая среди лучших
# 1                                    nan
# 2                                    nan
# 3                                    nan
# 4                                    nan
#
#                                               tags    article age_rating  \
# 0  Художественная литература ; Российский детектив  84(2Рос)6        16+
# 1                              Наука. Науковедение         72        12+
# 2                      Техника и технические науки          3         6+
# 3                 Литература для детей и юношества         84         6+
# 4                       Здравоохранение и медицина          5        12+
#
#   cover_url                                             unique
# 0      None    (Татьяна, Устинова, Витальевна, Канта, Призрак)
# 1      None                            (None, и, жизнь, Наука)
# 2      None  (зеленый, свет, на, Школа, (или, юного, пешехо...
# 3      None                                   (Мурзилка, None)
# 4      None                                   (None, Нарконет)

# %%
t = catalog[['unique', 'id']].groupby('unique')['id'].agg(list)


catalogid_to_uniquecatalogid = dict()

for ids in tqdm(t.values):
    for id_ in ids:
        catalogid_to_uniquecatalogid[id_] = ids[0]
        
len(catalogid_to_uniquecatalogid)

# В дальнейшем наложим эту маску на таблицу экземпляров
# Out:
# 100%|██████████| 690608/690608 [00:00<00:00, 2143837.19it/s]
# 1370457

# %% [markdown]
# # book_copy

# %%
book_copy = sql_read(f'''SELECT * FROM "HAHATON".data_bookcopy''')
print(book_copy.shape)
book_copy.head()
# Out:
# (12480044, 6)
#          id   inventory_id       barcode classification_id  sigles_id  book_id
# 0  12488544  09:0000120386  980007854120     84(2Рос=Рус)6      314.0        1
# 1  12488546  09:0000152427  980010247056     84(2Рос=Рус)6      320.0        1
# 2  12488542  09:0000240622  980000737154     84(2Рос=Рус)6      306.0        1
# 3  13671389  09:0000278133  980005475303     84(2Рос=Рус)6      308.0        1
# 4   7625486  05:0000257728  580001931461     84(2Рос=Рус)6      293.0        1

# %%
book_copy['book_id'] = book_copy['book_id'].map(catalogid_to_uniquecatalogid)

# %% [markdown]
# # booktake

# %%
booktake = sql_read(f'''SELECT * FROM "HAHATON".data_booktake''')
print(booktake.shape)
booktake.head()
# Out:
# (10411858, 7)
#         id   inventory_id       barcode                   take_at  \
# 0  4509252   Б06:00004188  680001558184 2019-11-26 15:00:00+00:00
# 1  4509253   Б06:00004195  680001558139 2019-11-26 15:00:00+00:00
# 2  4509254  07:0000120164  780002213645 2019-11-26 15:00:00+00:00
# 3  4509255  07:0000120151  780002213638 2019-11-26 15:00:00+00:00
# 4  4509256  07:0000120139  780002213621 2019-11-26 15:00:00+00:00
#
#                   return_at  condition_id  reader_id
# 0 2019-11-26 15:00:00+00:00          6548     331500
# 1 2019-11-26 15:00:00+00:00          6548     331500
# 2 2019-11-26 15:00:00+00:00          6548     331532
# 3 2019-11-26 15:00:00+00:00          6548     331532
# 4 2019-11-26 15:00:00+00:00          6548     331532

# %% [markdown]
# # Processing...

# %%
readers = readers.merge(booktake['reader_id'].value_counts().reset_index().rename(
    columns={'index': 'id',
             'reader_id': 'book_count'}),
              on='id', how='left')
print(readers.shape)
readers.head()
# Out:
# (562133, 4)
#        id  birth_date        age  book_count
# 0  366670  1974-10-14  46.079452         5.0
# 1  235264  1978-06-01  42.446575         NaN
# 2  133225  1976-01-06  44.849315         NaN
# 3  556716  1989-01-28  31.778082         NaN
# 4   52086  1955-08-14  65.260274         NaN

# %%
readers.fillna(0, inplace=True)

# %%
len(set(booktake['inventory_id']) - set(book_copy['inventory_id']))
# Out:
# 67799

# %%
booktake = booktake.merge(book_copy[['inventory_id', 'book_id']], on='inventory_id', how='left')
print(booktake.shape)
booktake.head()
# Out:
# (10411858, 8)
#         id   inventory_id       barcode                   take_at  \
# 0  4509252   Б06:00004188  680001558184 2019-11-26 15:00:00+00:00
# 1  4509253   Б06:00004195  680001558139 2019-11-26 15:00:00+00:00
# 2  4509254  07:0000120164  780002213645 2019-11-26 15:00:00+00:00
# 3  4509255  07:0000120151  780002213638 2019-11-26 15:00:00+00:00
# 4  4509256  07:0000120139  780002213621 2019-11-26 15:00:00+00:00
#
#                   return_at  condition_id  reader_id    book_id
# 0 2019-11-26 15:00:00+00:00          6548     331500    11169.0
# 1 2019-11-26 15:00:00+00:00          6548     331500    11169.0
# 2 2019-11-26 15:00:00+00:00          6548     331532   163585.0
# 3 2019-11-26 15:00:00+00:00          6548     331532  1250945.0
# 4 2019-11-26 15:00:00+00:00          6548     331532  1256585.0

# %%
booktake['book_id'].isna().mean()
# Out:
# 0.022243100126797734

# %%
booktake = booktake.merge(catalog[['id', 'author', 'title', 'year', 'series', 
                                   'tags', 'age_rating']].rename(columns={'id': 'book_id'}), 
                on='book_id', how='left')
print(booktake.shape)
booktake.head()
# Out:
# (10411858, 14)
#         id   inventory_id       barcode                   take_at  \
# 0  4509252   Б06:00004188  680001558184 2019-11-26 15:00:00+00:00
# 1  4509253   Б06:00004195  680001558139 2019-11-26 15:00:00+00:00
# 2  4509254  07:0000120164  780002213645 2019-11-26 15:00:00+00:00
# 3  4509255  07:0000120151  780002213638 2019-11-26 15:00:00+00:00
# 4  4509256  07:0000120139  780002213621 2019-11-26 15:00:00+00:00
#
#                   return_at  condition_id  reader_id    book_id  \
# 0 2019-11-26 15:00:00+00:00          6548     331500    11169.0
# 1 2019-11-26 15:00:00+00:00          6548     331500    11169.0
# 2 2019-11-26 15:00:00+00:00          6548     331532   163585.0
# 3 2019-11-26 15:00:00+00:00          6548     331532  1250945.0
# 4 2019-11-26 15:00:00+00:00          6548     331532  1256585.0
#
#             author                                        title   year  \
# 0             None                                    Новый мир  1925-
# 1             None                                    Новый мир  1925-
# 2  Абитан Анн-Мари                    Как мышонок учился читать   2014
# 3             None  Медвежонок Винни и его друзья. День чистоты   2016
# 4     Казалис Анна                     Мышонок Тим капризничает   2019
#
#         series                              tags age_rating
# 0          nan         Художественная литература        16+
# 1          nan         Художественная литература        16+
# 2          nan  Литература для детей и юношества         0+
# 3       Disney  Литература для детей и юношества         0+
# 4  Мышонок Тим  Литература для детей и юношества         0+

# %%
booktake = booktake[~booktake['book_id'].isna()].reset_index(drop=True)
print(booktake.shape)
# Out:
# (10180266, 14)

# %%
booktake = booktake.drop_duplicates(['reader_id', 'book_id', 'take_at']).reset_index(drop=True)
print(booktake.shape)
# Out:
# (7697843, 14)

# %%
# популярность книги

t = booktake.groupby('book_id')['year'].agg(['count']).reset_index()
t
# Out:
#           book_id  count
# 0             1.0   1884
# 1             2.0  26459
# 2             6.0     17
# 3             9.0      3
# 4            10.0      2
# ...           ...    ...
# 320129  1783590.0      1
# 320130  1783591.0      2
# 320131  1783601.0     47
# 320132  1783602.0     46
# 320133  1783614.0      7
#
# [320134 rows x 2 columns]

# %%
catalog = catalog.merge(t.rename(columns={'book_id': 'id'}), on='id', how='left')
catalog['count'] = catalog['count'].fillna(0)
catalog.head()
# Out:
#       id                       author  \
# 0      1  Устинова Татьяна Витальевна
# 1      2                         None
# 2  11185                         None
# 3  11157                         None
# 4  11161                         None
#
#                                                title    city  \
# 0                                      Призрак Канта  Москва
# 1                                      Наука и жизнь  Москва
# 2  Путешествие на зеленый свет (или Школа юного п...  Москва
# 3                                           Мурзилка  Москва
# 4                                           Нарконет  Москва
#
#                               publisher   year  \
# 0                                 Эксмо   2018
# 1  АНО Редакция журнала «Наука и жизнь»  1938-
# 2                                  Кедр   None
# 3           Редакция журнала "Мурзилка"  1924-
# 4                              Нарконет  1999-
#
#                                   series  \
# 0  Татьяна Устинова. Первая среди лучших
# 1                                    nan
# 2                                    nan
# 3                                    nan
# 4                                    nan
#
#                                               tags    article age_rating  \
# 0  Художественная литература ; Российский детектив  84(2Рос)6        16+
# 1                              Наука. Науковедение         72        12+
# 2                      Техника и технические науки          3         6+
# 3                 Литература для детей и юношества         84         6+
# 4                       Здравоохранение и медицина          5        12+
#
#   cover_url                                             unique    count
# 0      None    (Татьяна, Устинова, Витальевна, Канта, Призрак)   1884.0
# 1      None                            (None, и, жизнь, Наука)  26459.0
# 2      None  (зеленый, свет, на, Школа, (или, юного, пешехо...      0.0
# 3      None                                   (Мурзилка, None)  13905.0
# 4      None                                   (None, Нарконет)     11.0

# %%
catalog['rating'] = np.log(catalog['count'].values + 1)
catalog.head()
# Out:
#       id                       author  \
# 0      1  Устинова Татьяна Витальевна
# 1      2                         None
# 2  11185                         None
# 3  11157                         None
# 4  11161                         None
#
#                                                title    city  \
# 0                                      Призрак Канта  Москва
# 1                                      Наука и жизнь  Москва
# 2  Путешествие на зеленый свет (или Школа юного п...  Москва
# 3                                           Мурзилка  Москва
# 4                                           Нарконет  Москва
#
#                               publisher   year  \
# 0                                 Эксмо   2018
# 1  АНО Редакция журнала «Наука и жизнь»  1938-
# 2                                  Кедр   None
# 3           Редакция журнала "Мурзилка"  1924-
# 4                              Нарконет  1999-
#
#                                   series  \
# 0  Татьяна Устинова. Первая среди лучших
# 1                                    nan
# 2                                    nan
# 3                                    nan
# 4                                    nan
#
#                                               tags    article age_rating  \
# 0  Художественная литература ; Российский детектив  84(2Рос)6        16+
# 1                              Наука. Науковедение         72        12+
# 2                      Техника и технические науки          3         6+
# 3                 Литература для детей и юношества         84         6+
# 4                       Здравоохранение и медицина          5        12+
#
#   cover_url                                             unique    count  \
# 0      None    (Татьяна, Устинова, Витальевна, Канта, Призрак)   1884.0
# 1      None                            (None, и, жизнь, Наука)  26459.0
# 2      None  (зеленый, свет, на, Школа, (или, юного, пешехо...      0.0
# 3      None                                   (Мурзилка, None)  13905.0
# 4      None                                   (None, Нарконет)     11.0
#
#       rating
# 0   7.541683
# 1  10.183389
# 2   0.000000
# 3   9.540076
# 4   2.484907

# %%
ratings = booktake[['reader_id', 'book_id']].merge(
    catalog[['id', 'rating']].rename(columns={'id': 'book_id'}), 
    on='book_id', how='left').fillna(0)
print(ratings.shape)
ratings
# Out:
# (7697843, 3)
#          reader_id    book_id    rating
# 0           331500    11169.0  9.065892
# 1           331532   163585.0  6.800170
# 2           331532  1250945.0  4.276666
# 3           331532  1256585.0  4.919981
# 4            26581   909409.0  5.981414
# ...            ...        ...       ...
# 7697838     127636   155292.0  3.891820
# 7697839     322487   222308.0  5.159055
# 7697840     322487   452639.0  6.827629
# 7697841     273815   299759.0  3.951244
# 7697842     273815    11418.0  7.774436
#
# [7697843 rows x 3 columns]

# %%
ratings.to_csv('ratings.csv', index=False)

# %%
catalog.to_csv('books.csv', index=False)

# %%
ratings_test = sql_read(f'''SELECT * FROM "HAHATON".data_mlrating''')

# %%
catalog_test = sql_read(f'''SELECT * FROM "HAHATON".data_catalog''')

# %%
set(ratings_test['doc_id']) - set(catalog_test['id'])
# Out:
# set()

# %%
set(ratings['book_id']) - set(catalog_test['id'])
# Out:
# set()

# %%
readers
# Out:
#             id  birth_date        age  book_count
# 0       366670  1974-10-14  46.079452         5.0
# 1       235264  1978-06-01  42.446575         0.0
# 2       133225  1976-01-06  44.849315         0.0
# 3       556716  1989-01-28  31.778082         0.0
# 4        52086  1955-08-14  65.260274         0.0
# ...        ...         ...        ...         ...
# 562128  554754  1981-03-08  39.676712         0.0
# 562129  405813  2009-07-07  11.326027         6.0
# 562130  534901  2005-07-28  15.271233         4.0
# 562131   50142  2011-11-12   8.975342        51.0
# 562132  554755  1982-11-26  37.956164         0.0
#
# [562133 rows x 4 columns]

# %%
events = sql_read(f'''SELECT * FROM "HAHATON".data_event''')
print(events.shape)
events.head()
# Out:
# (41072, 28)
#    id                                               name     status  \
# 0   1                                           Врасплох  Завершено
# 1   2  Праздник Новогодней елки. Новогодний концерт в...  Завершено
# 2   3                Выставка к Рождеству "Сувенир Года"  Завершено
# 3   4                                      Зимняя сказка  Завершено
# 4   5                                  Почта Деда Мороза  Завершено
#
#                                host_name      host_type host_subclass  \
# 0          ГБУК г. Москвы «ДК «Нагатино»  Дома культуры           nan
# 1  ГАУК г. Москвы «Культурный центр ЗИЛ»  Дома культуры           nan
# 2            ГБУК г.Москвы ТКС «Орехово»  Дома культуры           nan
# 3            ГБУК г. Москвы «КЦ «Зодчие»  Дома культуры           nan
# 4              ГБУК г. Москвы "ДК "Темп"  Дома культуры           nan
#
#         price                                         event_type  \
# 0  бесплатное                                           выставка
# 1  бесплатное                 концерт, музыкальное представление
# 2  бесплатное                                           выставка
# 3  бесплатное  презентация, демонстрация, показетльные выступ...
# 4  бесплатное                                              акция
#
#                      event_focus is_holiday  ...  \
# 0                     антитеррор        nan  ...
# 1            культурно-досуговое   праздник  ...
# 2            культурно-досуговое   праздник  ...
# 3            культурно-досуговое        нет  ...
# 4  сохранение семейных ценностей   праздник  ...
#
#                           district                       area  \
# 0     Южный административный округ          Нагатинский Затон
# 1                              nan                        nan
# 2     Южный административный округ  Орехово-Борисово Северное
# 3  Западный административный округ                    Кунцево
# 4                              nan                        nan
#
#   is_disabled_friendly disability_type age_limit     age_group  \
# 0                  nan             nan         6  от 16 до 100
# 1                  nan             nan         0    от 5 до 14
# 2           недоступно             nan         6   от 15 до 80
# 3           недоступно             nan         0    от 5 до 80
# 4           недоступно             nan         0    от 6 до 99
#
#                                      target_audience age_group_floor  \
# 0  школьники, работающая молодежь, студенческая м...              16
# 1               дети дошкольного возраста, школьники               5
# 2  дети дошкольного возраста, школьники, работающ...              15
# 3               дети дошкольного возраста, школьники               5
# 4                                                nan               6
#
#   age_group_ceil mosru_id
# 0            100     3179
# 1             14      486
# 2             80     2100
# 3             80      254
# 4             99       78
#
# [5 rows x 28 columns]

# %%
age = 8

# %%
from datetime import date
date.today()
# Out:
# datetime.date(2020, 11, 1)

# %%
age = 55

np.random.seed(age)

# %%
events = sql_read(f'''SELECT * FROM "HAHATON".data_event''')
events = events[events.start_date > date.today()]

if age < 12:
    ids = np.random.choice(events[(events.age_group_ceil >= 0) & (events.age_group_ceil < 18)]['id'], 10, replace=False)
elif age < 18:
    ids = np.random.choice(events[(events.age_group_ceil >= 0) & (events.age_group_ceil < 40)]['id'], 10, replace=False)
elif age < 50:
    ids = np.random.choice(events[(events.age_group_ceil >= 18) & (events.age_group_ceil < 999)]['id'], 10, replace=False)
else:
    ids = np.random.choice(events[(events.age_group_ceil >= 55) & (events.age_group_ceil < 999)]['id'], 10, replace=False)
    
events[events.id.isin(ids)]
# Out:
#           id                                      name         status  \
# 32702  32688        Спектакль театра-студии "Традиция"     Уточняется
# 33813  33778                          Королева законов  Запланировано
# 34800  34757                         Новогодняя сказка     Уточняется
# 36397  37227                     Танцевальная практика  Запланировано
# 37214  37189             Танец - повод для знакомства   Запланировано
# 37223  37197                     Танцевальная практика  Запланировано
# 37242  37226                     Танцевальная практика  Запланировано
# 37304  37293                                 Фотоархив     Утверждено
# 37373  37360  Эдуард Успенский: личность, жизнь, герои  Запланировано
# 37384  37370                   Территория безопасности     Уточняется
#
#                               host_name      host_type host_subclass  \
# 32702      ГБУК г. Москвы «КЦ «Москвич»  Дома культуры           nan
# 33813          ГБУК г.Москвы «ЦБС ЮВАО»     Библиотеки           nan
# 34800     ГБУК г. Москвы «ТКС «Товарищ»  Дома культуры           nan
# 36397      ГБУК г.Москвы «ДК «Нагорный»  Дома культуры           nan
# 37214      ГБУК г.Москвы «ДК «Нагорный»  Дома культуры           nan
# 37223      ГБУК г.Москвы «ДК «Нагорный»  Дома культуры           nan
# 37242      ГБУК г.Москвы «ДК «Нагорный»  Дома культуры           nan
# 37304          ГБУК г. Москвы «ЦБС ЦАО»     Библиотеки           nan
# 37373       ГБУК г. Москвы "КЦ"Акулово"  Дома культуры           nan
# 37384  ГБУК г. Москвы «ДК «Содружество»  Дома культуры           nan
#
#                                    price  \
# 32702                         бесплатное
# 33813                         бесплатное
# 34800                         бесплатное
# 36397  платное (от 150 руб. до 150 руб.)
# 37214  платное (от 150 руб. до 150 руб.)
# 37223  платное (от 150 руб. до 150 руб.)
# 37242  платное (от 150 руб. до 150 руб.)
# 37304                         бесплатное
# 37373                         бесплатное
# 37384                         бесплатное
#
#                                               event_type          event_focus  \
# 32702  представление, спектакль, инсценировка, перфом...  культурно-досуговое
# 33813                                             лекция     просветительское
# 34800  представление, спектакль, инсценировка, перфом...  культурно-досуговое
# 36397                            танцевальный вечер, бал  культурно-досуговое
# 37214                            игра, игровая программа  культурно-досуговое
# 37223                            танцевальный вечер, бал  культурно-досуговое
# 37242                            танцевальный вечер, бал  культурно-досуговое
# 37304                          встреча, творческий вечер  культурно-досуговое
# 37373                          встреча, творческий вечер  культурно-досуговое
# 37384                                             лекция           антитеррор
#
#       is_holiday  ...                                 district          area  \
# 32702        нет  ...     Юго-Восточный административный округ  Текстильщики
# 33813        nan  ...     Юго-Восточный административный округ    Некрасовка
# 34800    событие  ...  Северо-Восточный административный округ     Ростокино
# 36397        nan  ...             Южный административный округ      Нагорный
# 37214        нет  ...             Южный административный округ      Нагорный
# 37223        nan  ...             Южный административный округ      Нагорный
# 37242        nan  ...             Южный административный округ      Нагорный
# 37304        нет  ...       Центральный административный округ     Басманный
# 37373        nan  ...         Восточный административный округ     Восточный
# 37384        нет  ...  Северо-Восточный административный округ  Алексеевский
#
#       is_disabled_friendly              disability_type age_limit  \
# 32702           недоступно                          nan         6
# 33813             доступно  Опорно-двигательный аппарат        12
# 34800           недоступно                          nan         0
# 36397                  nan                          nan        18
# 37214           недоступно                          nan        18
# 37223                  nan                          nan        18
# 37242                  nan                          nan        18
# 37304             доступно  Опорно-двигательный аппарат        18
# 37373             доступно  Опорно-двигательный аппарат         6
# 37384           недоступно                          nan         6
#
#          age_group                                    target_audience  \
# 32702   от 0 до 99  школьники, работающая молодежь, студенческая м...
# 33813   от 0 до 99  школьники, работающая молодежь, студенческая м...
# 34800  от 12 до 80  дети дошкольного возраста, школьники, работающ...
# 36397  от 30 до 70                                                nan
# 37214  от 50 до 95                                           взрослые
# 37223  от 50 до 90                                                nan
# 37242  от 30 до 70                                                nan
# 37304  от 18 до 75         работающая молодежь, студенческая молодежь
# 37373  от 6 до 100  школьники, работающая молодежь, студенческая м...
# 37384   от 6 до 80  дети дошкольного возраста, школьники, работающ...
#
#       age_group_floor age_group_ceil mosru_id
# 32702               0             99     1511
# 33813               0             99     1577
# 34800              12             80     1443
# 36397              30             70      145
# 37214              50             95       92
# 37223              50             90      102
# 37242              30             70      143
# 37304              18             75      481
# 37373               6            100      964
# 37384               6             80     1066
#
# [10 rows x 28 columns]
